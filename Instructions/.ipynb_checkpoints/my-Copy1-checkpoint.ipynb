# %% [markdown]
# # WeatherPy

# %% [markdown]
# Analysis:
# * Observed trend 1
# * Observed trend 2
# * Observed trend 3

# %%
# dependencies
from citipy import citipy
from random import uniform
from config import api_key
import requests
import numpy
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# base_url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# # Generate Cities List

# %%
# generate random latitudes and longitudes
total = 700
lat_samples = [numpy.random.uniform(-90, 90) for i in range(total)]
lon_samples = [numpy.random.uniform(-180, 180) for i in range(total)]

# prepare lists for storing data
result_samples = []
city_samples = []
country_samples = []

# iterate through cities
for i in range(total):
    lat = lat_samples[i]
    lon = lon_samples[i]

    # find the nearest city to that pair of coordinates
    # find the city name and country code
    result = citipy.nearest_city(lat, lon)
    city = result.city_name
    country = result.country_code

    # append data to lists
    result_samples.append(result)
    city_samples.append(city)
    country_samples.append(country)

city_samples
# Out:
# ['marsaxlokk',
#  'zlotow',
#  'severo-kurilsk',
#  'pacifica',
#  'erdenet',
#  'tumannyy',
#  'baykalsk',
#  'ushuaia',
#  'new norfolk',
#  'bredasdorp',
#  'ahipara',
#  'butaritari',
#  'rikitea',
#  'punta arenas',
#  'kapaa',
#  'ushuaia',
#  'kapaa',
#  'mayumba',
#  'butembo',
#  'teeli',
#  'lagos',
#  'butaritari',
#  'hecun',
#  'qaanaaq',
#  'karaton',
#  'chokurdakh',
#  'ahuimanu',
#  'jaciara',
#  'rikitea',
#  'saint-philippe',
#  'illoqqortoormiut',
#  'nanyamba',
#  'rikitea',
#  'codrington',
#  'leningradskiy',
#  'waingapu',
#  'ushuaia',
#  'tasiilaq',
#  'jumla',
#  'yellowknife',
#  'marzuq',
#  'progreso',
#  'cape town',
#  'norman wells',
#  'malanje',
#  'banning',
#  'qaanaaq',
#  'kapaa',
#  'mataura',
#  'dunedin',
#  'shyryayeve',
#  'puerto ayora',
#  'bluff',
#  'cairns',
#  'alice springs',
#  'albany',
#  'port alfred',
#  'kovdor',
#  'jamestown',
#  'qaanaaq',
#  'dzhusaly',
#  'barrow',
#  'kirkwall',
#  'kigoma',
#  'ushuaia',
#  'longyearbyen',
#  'kodiak',
#  'hermanus',
#  'kodiak',
#  'atuona',
#  'kavaratti',
#  'rio gallegos',
#  'kapaa',
#  'moose factory',
#  'khatanga',
#  'ushuaia',
#  'norman wells',
#  'vaini',
#  'kindu',
#  'mednogorsk',
#  'iquitos',
#  'castro',
#  'cayenne',
#  'myaundzha',
#  'punta arenas',
#  'cidreira',
#  'qaanaaq',
#  'cidreira',
#  'port hardy',
#  'port alfred',
#  'miramar',
#  'grand gaube',
#  'palmer',
#  'taolanaro',
#  'kruisfontein',
#  'roma',
#  'boyolangu',
#  'kapaa',
#  'hithadhoo',
#  'tumannyy',
#  'hilo',
#  'puerto ayora',
#  'faya',
#  'kapaa',
#  'padang',
#  'ushuaia',
#  'meiktila',
#  'rikitea',
#  'longyearbyen',
#  'illoqqortoormiut',
#  'jamestown',
#  'pisco',
#  'lebu',
#  'kieta',
#  'ovalle',
#  'ribeira grande',
#  'parana',
#  'saleaula',
#  'rikitea',
#  'mataura',
#  'zyryanka',
#  'vaini',
#  'norman wells',
#  'cape town',
#  'rikitea',
#  'balikpapan',
#  'barentsburg',
#  'rikitea',
#  'barentsburg',
#  'kapaa',
#  'pochutla',
#  'hobart',
#  'goma',
#  'east london',
#  'tasiilaq',
#  'grindavik',
#  'jamestown',
#  'vaitupu',
#  'anadyr',
#  'cap-aux-meules',
#  'rikitea',
#  'tuktoyaktuk',
#  'jamestown',
#  'turukhansk',
#  'nanortalik',
#  'presque isle',
#  'hermanus',
#  'douentza',
#  'orange walk',
#  'luderitz',
#  'hermanus',
#  'bluff',
#  'ushuaia',
#  'abeche',
#  'shabo',
#  'ponta do sol',
#  'bredasdorp',
#  'haibowan',
#  'los llanos de aridane',
#  'hithadhoo',
#  'sobolevo',
#  'sumbawa',
#  'victoria',
#  'busselton',
#  'punta arenas',
#  'kapaa',
#  'les trois-ilets',
#  'kalevala',
#  'topolobampo',
#  'tasiilaq',
#  'necochea',
#  'hermanus',
#  'ushuaia',
#  'ushuaia',
#  'luwuk',
#  'mataura',
#  'rikitea',
#  'hilo',
#  'punta arenas',
#  'punta arenas',
#  'muros',
#  'vaini',
#  'carnarvon',
#  'puerto rico',
#  'nizhniy tsasuchey',
#  'fort nelson',
#  'dikson',
#  'guilin',
#  'toguchin',
#  'tuktoyaktuk',
#  'hithadhoo',
#  'chuy',
#  'puerto ayora',
#  'thompson',
#  'mataura',
#  'hithadhoo',
#  'bredasdorp',
#  'mandapam',
#  'vaini',
#  'puerto ayora',
#  'ushuaia',
#  'thanh hoa',
#  'natal',
#  'mataura',
#  'torbay',
#  'champasak',
#  'tuktoyaktuk',
#  'samusu',
#  'saint anthony',
#  'rikitea',
#  'harper',
#  'mahon',
#  'ponta do sol',
#  'albany',
#  'san patricio',
#  'ushuaia',
#  'ushuaia',
#  'albany',
#  'santiago del estero',
#  'barentsburg',
#  'iracoubo',
#  'busselton',
#  'valparaiso',
#  'ushuaia',
#  'albany',
#  'bluff',
#  'bredasdorp',
#  'port alfred',
#  'port alfred',
#  'ovalle',
#  'vaini',
#  'barrow',
#  'faya',
#  'vaini',
#  'mersing',
#  'iqaluit',
#  'grand river south east',
#  'luba',
#  'albany',
#  'lorengau',
#  'hobart',
#  'pevek',
#  'petropavlovsk-kamchatskiy',
#  'berlevag',
#  'ust-tsilma',
#  'souillac',
#  'port alfred',
#  'gigante',
#  'hilo',
#  'itoman',
#  'dalby',
#  'broome',
#  'saleaula',
#  'ushuaia',
#  'chinhoyi',
#  'qui nhon',
#  'ushuaia',
#  'wiarton',
#  'tasiilaq',
#  'vao',
#  'mataura',
#  'itumba',
#  'fort nelson',
#  'svetlogorsk',
#  'ushuaia',
#  'chernyshevskiy',
#  'laje',
#  'padang',
#  'hualmay',
#  'zhezkazgan',
#  'los llanos de aridane',
#  'turayf',
#  'bluff',
#  'tlanchinol',
#  'guerrero negro',
#  'ushuaia',
#  'butaritari',
#  'taolanaro',
#  'rome',
#  'port lincoln',
#  'jamestown',
#  'cockburn town',
#  'butaritari',
#  'punta arenas',
#  'busselton',
#  'saint-philippe',
#  'westport',
#  'nikolskoye',
#  'albany',
#  'belushya guba',
#  'jamestown',
#  'busselton',
#  'santa fe',
#  'acara',
#  'general teran',
#  'mataura',
#  'garowe',
#  'saint-philippe',
#  'cherskiy',
#  'hermanus',
#  'ribeira grande',
#  'puerto ayora',
#  'souillac',
#  'namatanai',
#  'teshie',
#  'san quintin',
#  'nuuk',
#  'tuktoyaktuk',
#  'tsihombe',
#  'vaini',
#  'mehamn',
#  'barrow',
#  'attawapiskat',
#  'taolanaro',
#  'albany',
#  'saint-pierre',
#  'kincardine',
#  'hermanus',
#  'rikitea',
#  'kavaratti',
#  'tsihombe',
#  'mys shmidta',
#  'kampong cham',
#  'kavieng',
#  'castro',
#  'kapaa',
#  'vila',
#  'kang',
#  'wanning',
#  'grand river south east',
#  'mys shmidta',
#  'albany',
#  'mataura',
#  'asau',
#  'busselton',
#  'atuona',
#  'thompson',
#  'emerald',
#  'talnakh',
#  'ribeira grande',
#  'ushuaia',
#  'mataura',
#  'punta arenas',
#  'lewistown',
#  'ushuaia',
#  'zhezkazgan',
#  'puerto ayora',
#  'franklin park',
#  'busselton',
#  'jabiru',
#  'tasiilaq',
#  'punta arenas',
#  'hermanus',
#  'ilulissat',
#  'lyngseidet',
#  'bahir dar',
#  'tripoli',
#  'klaksvik',
#  'geraldton',
#  'yerbogachen',
#  'norman wells',
#  'rikitea',
#  'dikson',
#  'yellowknife',
#  'albany',
#  'kangaba',
#  'jiuquan',
#  'batemans bay',
#  'vardo',
#  'klaksvik',
#  'salvador',
#  'san jose',
#  'souillac',
#  'asau',
#  'chardara',
#  'vaini',
#  'albany',
#  'khatanga',
#  'avarua',
#  'victor harbor',
#  'jamestown',
#  'busselton',
#  'kirgiz-miyaki',
#  'behbahan',
#  'desaguadero',
#  'turukhansk',
#  'eureka',
#  'ushuaia',
#  'scarborough',
#  'mirnyy',
#  'constitucion',
#  'upernavik',
#  'tarudant',
#  'broome',
#  'hobart',
#  'punta arenas',
#  'vaini',
#  'ushuaia',
#  'kavaratti',
#  'te anau',
#  'salalah',
#  'busselton',
#  'cape town',
#  'luderitz',
#  'albany',
#  'hofn',
#  'amderma',
#  'puerto ayora',
#  'zhangjiakou',
#  'port alfred',
#  'kaitangata',
#  'rawannawi',
#  'nuuk',
#  'yar-sale',
#  'avera',
#  'yellowknife',
#  'harer',
#  'ushuaia',
#  'nemuro',
#  'port hedland',
#  'namibe',
#  'hermanus',
#  'ushuaia',
#  'khatanga',
#  'road town',
#  'katherine',
#  'yellowknife',
#  'hithadhoo',
#  'dibaya',
#  'acapulco',
#  'punta arenas',
#  'bredasdorp',
#  'sobolevo',
#  'tiksi',
#  'aklavik',
#  'bethel',
#  'bluff',
#  'jamestown',
#  'butaritari',
#  'marystown',
#  'butaritari',
#  'ponta do sol',
#  'warqla',
#  'upernavik',
#  'belushya guba',
#  'codrington',
#  'avarua',
#  'mumbwa',
#  'diffa',
#  'kapaa',
#  'itoman',
#  'elmadag',
#  'andevoranto',
#  'avarua',
#  'cazaje',
#  'chateaubelair',
#  'cape town',
#  'pittsburg',
#  'pevek',
#  'rikitea',
#  'hobart',
#  'kharp',
#  'anloga',
#  'sur',
#  'port alfred',
#  'carnarvon',
#  'muriti',
#  'itaituba',
#  'hobart',
#  'mataura',
#  'belushya guba',
#  'georgetown',
#  'ponta do sol',
#  'santa rita',
#  'taolanaro',
#  'dunedin',
#  'yaan',
#  'punta arenas',
#  'cidreira',
#  'sayansk',
#  'litovko',
#  'hunza',
#  'gobabis',
#  'albany',
#  'mackay',
#  'tabou',
#  'richards bay',
#  'torbay',
#  'opuwo',
#  'kattivakkam',
#  'san patricio',
#  'east london',
#  'mataura',
#  'vaini',
#  'togur',
#  'castro',
#  'puri',
#  'chara',
#  'georgetown',
#  'kavieng',
#  'bengkulu',
#  'bainbridge',
#  'east london',
#  'vaini',
#  'byron bay',
#  'busselton',
#  'provideniya',
#  'port alfred',
#  'saint-francois',
#  'codajas',
#  'brae',
#  'qaanaaq',
#  'nikolskoye',
#  'cidreira',
#  'loandjili',
#  'mataura',
#  'tadine',
#  'victoria',
#  'laguna',
#  'ushuaia',
#  'esperance',
#  'souillac',
#  'barentsburg',
#  'punta arenas',
#  'ushuaia',
#  'calama',
#  'robertson',
#  'busselton',
#  'college',
#  'tasiilaq',
#  'amurzet',
#  'coquimbo',
#  'rikitea',
#  'rikitea',
#  'rikitea',
#  'abha',
#  'dikson',
#  'rikitea',
#  'albany',
#  'mataura',
#  'datong',
#  'cayenne',
#  'porto novo',
#  'naliya',
#  'verkhnevilyuysk',
#  'albany',
#  'cape town',
#  'mataura',
#  'amderma',
#  'nizhneyansk',
#  'sentyabrskiy',
#  'iqaluit',
#  'vagur',
#  'longlac',
#  'tuktoyaktuk',
#  'kyren',
#  'hilo',
#  'bambous virieux',
#  'nikolskoye',
#  'turayf',
#  'umea',
#  'pacific grove',
#  'oranjestad',
#  'sonoita',
#  'grand gaube',
#  'letlhakane',
#  'port alfred',
#  'ribeira grande',
#  'taitung',
#  'punta arenas',
#  'rikitea',
#  'souillac',
#  'lagoa',
#  'rikitea',
#  'salalah',
#  'arraial do cabo',
#  'honningsvag',
#  'yar-sale',
#  'illoqqortoormiut',
#  'puerto ayora',
#  'goderich',
#  'rabo de peixe',
#  'mukhen',
#  'cidreira',
#  'busselton',
#  'kaitangata',
#  'belushya guba',
#  'aksarka',
#  'mys shmidta',
#  'ushuaia',
#  'satitoa',
#  'esperance',
#  'ryotsu',
#  'rikitea',
#  'ushuaia',
#  'cabo san lucas',
#  'teahupoo',
#  'taksimo',
#  'hasaki',
#  'bengkulu',
#  'jamestown',
#  'hermanus',
#  'rikitea',
#  'rikitea',
#  'bluff',
#  'williams lake',
#  'tyukhtet',
#  'cape town',
#  'presidencia roque saenz pena',
#  'bambous virieux',
#  'hilo',
#  'qaanaaq',
#  'talnakh',
#  'tidore',
#  'geraldton',
#  'neyshabur',
#  'illoqqortoormiut',
#  'tasbuget',
#  'bereda',
#  'saint george',
#  'jamestown',
#  'klaksvik',
#  'redlands',
#  'puerto ayora',
#  'georgetown',
#  'umzimvubu',
#  'port moresby',
#  'kenai',
#  'kapaa',
#  'mar del plata',
#  'cape town',
#  'bonfim',
#  'rikitea',
#  'new norfolk',
#  'kinsale',
#  'busselton',
#  'laplace',
#  'vestmannaeyjar',
#  'taolanaro',
#  'kruisfontein',
#  'novopokrovka',
#  'nehe',
#  'busselton',
#  'port alfred',
#  'hasaki',
#  'ushuaia',
#  'malyn',
#  'vostok',
#  'vardo',
#  'severodvinsk',
#  'juba',
#  'ushuaia',
#  'vila franca do campo',
#  'tuktoyaktuk',
#  'hermanus',
#  'castro',
#  'preobrazheniye',
#  'cape town',
#  'atuona',
#  'riyadh',
#  'pontianak',
#  'rikitea',
#  'bluff',
#  'port blair',
#  'volsk',
#  'hami',
#  'castro',
#  'busselton',
#  'saldanha',
#  'wewak',
#  'cidreira',
#  'guerrero negro',
#  'zhezkazgan',
#  'tarko-sale',
#  'cap-haitien',
#  'vaini',
#  'hilo',
#  'rikitea',
#  'roebourne',
#  'port alfred',
#  'tuktoyaktuk',
#  'borlange',
#  'taolanaro',
#  'methoni',
#  'new norfolk',
#  'ban dung',
#  'shymkent',
#  'westport',
#  'labuhan',
#  'khatanga',
#  'road town',
#  'san cristobal',
#  'lebu',
#  'creston',
#  'yellowknife',
#  'avarua',
#  'mweka',
#  'sentyabrskiy',
#  'hasaki',
#  'hobyo']

# %% [markdown]
# # Perform API Calls

# %%
# test to get response for one city
city = "paris"
params = {"appid" : api_key, "q" : city, "units" : "imperial"}
response = requests.get(base_url, params)
data = response.json()

# %%
# iterate through cities and perform API calls
data_list = []
city_list = []
country_list = []
date_list = []
lat_list = []
lon_list = []
cloudiness_list = []
humidity_list = []
temp_list = []
wind_speed_list = []
n = 0

# loop through cities to make api calls
for i in range(total):
    city = city_samples[i]
    params = {"appid" : api_key, "q" : city, "units" : "imperial"}
    response = requests.get(base_url, params)
    
    # only store data into lists when http status code is 200 (ok)
    if response.status_code == 200:
        data = response.json()
        
        # append data to lists
        city_list.append(city)
        country_list.append(data["sys"]["country"])
        date_list.append(data["dt"])
        lat_list.append(lat_samples[i])
        lon_list.append(lon_samples[i])
        data_list.append(data)
        cloudiness_list.append(data["clouds"]["all"])
        humidity_list.append(data["main"]["humidity"])
        temp_list.append(data["main"]["temp_max"])
        wind_speed_list.append(data["wind"]["speed"])

        # print city number, name and url
        print(f"Processing Record {n%50+1} of Set {int(n/50+1)} | {city}")
        print(response.url)
# Out:
# Processing Record 1 of Set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=san+patricio&units=imperial
# Processing Record 1 of Set 1 | staropesterevo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=staropesterevo&units=imperial
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ushuaia&units=imperial
# Processing Record 1 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=mataura&units=imperial
# Processing Record 1 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=cherskiy&units=imperial
# Processing Record 1 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=mar+del+plata&units=imperial
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ushuaia&units=imperial
# Processing Record 1 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=georgetown&units=imperial
# Processing Record 1 of Set 1 | kochki
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=kochki&units=imperial
# Processing Record 1 of Set 1 | hanford
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hanford&units=imperial
# Processing Record 1 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=busselton&units=imperial
# Processing Record 1 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=airai&units=imperial
# Processing Record 1 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=tuatapere&units=imperial
# Processing Record 1 of Set 1 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ballina&units=imperial
# Processing Record 1 of Set 1 | lishu
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=lishu&units=imperial
# Processing Record 1 of Set 1 | foix
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=foix&units=imperial
# Processing Record 1 of Set 1 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=plettenberg+bay&units=imperial
# Processing Record 1 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=mataura&units=imperial
# Processing Record 1 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=chuy&units=imperial
# Processing Record 1 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=upernavik&units=imperial
# Processing Record 1 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=georgetown&units=imperial
# Processing Record 1 of Set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=aykhal&units=imperial
# Processing Record 1 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=vaini&units=imperial
# Processing Record 1 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=cape+town&units=imperial
# Processing Record 1 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=atuona&units=imperial
# Processing Record 1 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=georgetown&units=imperial
# Processing Record 1 of Set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=sao+joao+da+barra&units=imperial
# Processing Record 1 of Set 1 | yumen
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=yumen&units=imperial
# Processing Record 1 of Set 1 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hobyo&units=imperial
# Processing Record 1 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=carnarvon&units=imperial
# Processing Record 1 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=vaini&units=imperial
# Processing Record 1 of Set 1 | nizhniy baskunchak
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=nizhniy+baskunchak&units=imperial
# Processing Record 1 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=provideniya&units=imperial
# Processing Record 1 of Set 1 | yuanping
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=yuanping&units=imperial
# Processing Record 1 of Set 1 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=kalmunai&units=imperial
# Processing Record 1 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=port+elizabeth&units=imperial
# Processing Record 1 of Set 1 | surazh
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=surazh&units=imperial
# Processing Record 1 of Set 1 | lundazi
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=lundazi&units=imperial
# Processing Record 1 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=narsaq&units=imperial
# Processing Record 1 of Set 1 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=tarko-sale&units=imperial
# Processing Record 1 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=bredasdorp&units=imperial
# Processing Record 1 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=nanortalik&units=imperial
# Processing Record 1 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=tasiilaq&units=imperial
# Processing Record 1 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=mataura&units=imperial
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ushuaia&units=imperial
# Processing Record 1 of Set 1 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=naze&units=imperial
# Processing Record 1 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=new+norfolk&units=imperial
# Processing Record 1 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=kaitangata&units=imperial
# Processing Record 1 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=rikitea&units=imperial
# Processing Record 1 of Set 1 | sesori
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=sesori&units=imperial
# Processing Record 1 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=kapaa&units=imperial
# Processing Record 1 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hermanus&units=imperial
# Processing Record 1 of Set 1 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=marawi&units=imperial
# Processing Record 1 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=airai&units=imperial
# Processing Record 1 of Set 1 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=prince+rupert&units=imperial
# Processing Record 1 of Set 1 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=havoysund&units=imperial
# Processing Record 1 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=bredasdorp&units=imperial
# Processing Record 1 of Set 1 | maymyo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=maymyo&units=imperial
# Processing Record 1 of Set 1 | abha
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=abha&units=imperial
# Processing Record 1 of Set 1 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=necochea&units=imperial
# Processing Record 1 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=geraldton&units=imperial
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hobart&units=imperial
# Processing Record 1 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=chokurdakh&units=imperial
# Processing Record 1 of Set 1 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=lata&units=imperial
# Processing Record 1 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=georgetown&units=imperial
# Processing Record 1 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=arraial+do+cabo&units=imperial
# Processing Record 1 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=new+norfolk&units=imperial
# Processing Record 1 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=butaritari&units=imperial
# Processing Record 1 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=bethel&units=imperial
# Processing Record 1 of Set 1 | la salle
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=la+salle&units=imperial
# Processing Record 1 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=busselton&units=imperial
# Processing Record 1 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hilo&units=imperial
# Processing Record 1 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ribeira+grande&units=imperial
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=hobart&units=imperial
# Processing Record 1 of Set 1 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=buraydah&units=imperial
# Processing Record 1 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=salalah&units=imperial
# Processing Record 1 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=bluff&units=imperial
# Processing Record 1 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=port+elizabeth&units=imperial
# Processing Record 1 of Set 1 | arecibo
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=arecibo&units=imperial
# Processing Record 1 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=cape+town&units=imperial
# Processing Record 1 of Set 1 | briancon
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=briancon&units=imperial
# Processing Record 1 of Set 1 | staraya toropa
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=staraya+toropa&units=imperial
# Processing Record 1 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=albany&units=imperial
# Processing Record 1 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=nanortalik&units=imperial
# Processing Record 1 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=bredasdorp&units=imperial
# Processing Record 1 of Set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=lavrentiya&units=imperial
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=ushuaia&units=imperial
# Processing Record 1 of Set 1 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=nishihara&units=imperial
# Processing Record 1 of Set 1 | sayanogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=sayanogorsk&units=imperial
# Processing Record 1 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=barrow&units=imperial
# Processing Record 1 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=port+alfred&units=imperial
# Processing Record 1 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=puerto+ayora&units=imperial
# Processing Record 1 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f5577870a4fe514c0a6c56ee569c5c7b&q=cape+town&units=imperial

# %%
# generate a dataframe
df = pd.DataFrame(
    {
        "City" : city_list,
        "Cloudiness" : cloudiness_list,
        "Country" : country_list,
        "Date": date_list,
        "Humidity" : humidity_list,
        "Lat" : lat_list,
        "Lng" : lon_list,
        "Max Temp" : temp_list,
        "Wind Speed" : wind_speed_list
    }
)

# format latitude and longitude to 2 decimal points
df["Lat"] = df["Lat"].map("{:.2f}".format)
df["Lng"] = df["Lng"].map("{:.2f}".format)

# convert data format of latitude and longitude to numeric
df["Lat"] = pd.to_numeric(df["Lat"])
df["Lng"] = pd.to_numeric(df["Lng"])

# count number of all rows that's not NaN, in each column
df.count()
# Out:
# City          93
# Cloudiness    93
# Country       93
# Date          93
# Humidity      93
# Lat           93
# Lng           93
# Max Temp      93
# Wind Speed    93
# dtype: int64

# %%
# display the dataframe
df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    san patricio          56      PY  1526611215        87   3.63 -114.65
# 1  staropesterevo          76      RU  1526611773        83  54.50   86.45
# 2         ushuaia           0      AR  1526608800        80 -89.13  -50.83
# 3         mataura          56      NZ  1526611773        80 -38.63 -157.33
# 4        cherskiy          12      RU  1526611773        77  80.43  158.13
#
#    Max Temp  Wind Speed
# 0     68.84        1.59
# 1     36.62        6.96
# 2     35.60        2.26
# 3     50.03       13.44
# 4     43.73        4.72

# %% [markdown]
# # Temperature (F) vs. Latitude Plot

# %%
# Set style, linewidth of borders, and font
plt.style.use("dark_background")
matplotlib.rcParams["axes.linewidth"] = 3
matplotlib.rcParams.update({"font.size": 15})

# %%
# make a scatter plot
df.plot(kind="scatter", x="Lat", y="Max Temp", figsize=(10,6))
plt.title("City Temperature (F) vs. Latitude (05/17/2018)", fontsize=20, fontweight="bold")
plt.xlabel("Latitude", weight="bold")
plt.ylabel("Max Temperature (F)", weight="bold")
plt.grid(ls="--")
plt.xlim(-90, 90)
plt.show()

# %% [markdown]
# # Humidity (%) vs. Latitude Plot

# %%
# make a scatter plot
df.plot(kind="scatter", x="Lat", y="Humidity", figsize=(10,6))
plt.title("Humidity (%) vs. Latitude (05/17/2018)", fontsize=20, fontweight="bold")
plt.xlabel("Latitude", weight="bold")
plt.ylabel("Humidity (%)", weight="bold")
plt.grid(ls="--")
plt.xlim(-90, 90)
plt.show()

# %% [markdown]
# # Cloudiness (%) vs. Latitude Plot

# %%
# make a scatter plot
df.plot(kind="scatter", x="Lat", y="Cloudiness", figsize=(10,6))
plt.title("Cloudiness (%) vs. Latitude (05/17/2018)", fontsize=20, fontweight="bold")
plt.xlabel("Latitude", weight="bold")
plt.ylabel("Cloudiness (%)", weight="bold")
plt.grid(ls="--")
plt.xlim(-90, 90)
plt.show()

# %% [markdown]
# # Wind Speed (mph) vs. Latitude Plot

# %%
# make a scatter plot
df.plot(kind="scatter", x="Lat", y="Wind Speed", figsize=(10,6))
plt.title("Wind Speed (mph) vs. Latitude (05/17/2018)", fontsize=20, fontweight="bold")
plt.xlabel("Latitude", weight="bold")
plt.ylabel("Wind Speed (mph)", weight="bold")
plt.grid(ls="--")
plt.xlim(-90, 90)
plt.show()
